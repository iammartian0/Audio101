# %% [markdown]
# <a href="https://colab.research.google.com/github/iammartian0/Audio101/blob/main/Audio_applications.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers datasets[audio]

# %%
from datasets import load_dataset
from datasets import Audio

minds = load_dataset("PolyAI/minds14", name="en-AU", split="train")
minds = minds.cast_column("audio", Audio(sampling_rate=16_000))

# %% [markdown]
# Experimenting with pre-trained models which can perform inference on the fly

# %% [markdown]
# **Audio Classification**

# %%
from transformers import pipeline

classifier = pipeline(
    "audio-classification",
    model="anton-l/xtreme_s_xlsr_300m_minds14",
)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/2.73k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/1.26G [00:00<?, ?B/s]
# Downloading (…)rocessor_config.json:   0%|          | 0.00/212 [00:00<?, ?B/s]

# %%
example = minds[10]

# %%
classifier(example["audio"]["array"])
# Out:
# [{'score': 0.9780802726745605, 'label': 'pay_bill'},
#  {'score': 0.004805247765034437, 'label': 'high_value_payment'},
#  {'score': 0.00471510412171483, 'label': 'direct_debit'},
#  {'score': 0.004183368757367134, 'label': 'freeze'},
#  {'score': 0.0021684670355170965, 'label': 'card_issues'}]

# %%
id2label = minds.features["intent_class"].int2str
id2label(example["intent_class"])
# Out:
# 'pay_bill'

# %% [markdown]
# **Automatic Speech Recognition**

# %%
from transformers import pipeline

asr = pipeline("automatic-speech-recognition")
# Out:
# No model was supplied, defaulted to facebook/wav2vec2-base-960h and revision 55bb623 (https://huggingface.co/facebook/wav2vec2-base-960h).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.60k [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/378M [00:00<?, ?B/s]
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/wav2vec2-base-960h and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Downloading (…)okenizer_config.json:   0%|          | 0.00/163 [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/291 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/85.0 [00:00<?, ?B/s]
# Downloading (…)rocessor_config.json:   0%|          | 0.00/159 [00:00<?, ?B/s]

# %%
for i in range(10):
  example = minds[i]
  print(asr(example["audio"]["array"]))
  print(example["english_transcription"])
# Out:
# {'text': 'I WOULD LIKE TO PAY MY ELECTRICITY BILL USING MY CAD CAN YOU PLEASE ASSIST'}
# I would like to pay my electricity bill using my card can you please assist
# {'text': 'ELL I LIKE TO PAY FOR BILL IM I OUGHT I SHALL LIKE TO MAK  A PAYMENT BUT AM DE COULD JUMP ME OUT'}
# hello I like to pay for Bill I would actually like to make a payment but yeah could you help me
# {'text': 'I A MILL'}
# pay a bill
# {'text': 'MY CREDIT GOD PAYMENT IS JUNE'}
# my credit card payment is due
# {'text': "WHY I'D LIKE TO MAKE A YE PAYMENT FOR A BILL"}
# hi I would like to make a new payment for a bill
# {'text': 'HENNO MY CRITICOT BILLITYU'}
# hello my credit card bills due
# {'text': "HULLO IAVE JUST RECENTLY OPENED UP AN ACCOUNT WITH YOUR BANK AND I WANTED TO FIND OUT HOW I CAN GO ABOUT PAYING BILLS USING MY A SAVING'S ACCOUNT"}
# hello I've just recently opened up an account with your bank and I wanted to find out how I can go about paying bills using my savings account
# {'text': "HE THAR I'M I'M JUST CAING ABOUT MAKING IM A PAYMENT FOR BILL THAT I'VE GOT COMING UP I'M JUST WONDERING IF YOU COULD LEND ME A HAND WITH THAT PLEACE"}
# hey there I'm just calling about making a payment for Bill that I've got coming up I'm just wondering if you could lend me a hand with that please
# {'text': "I OU'D LIKE TO PAY A BILL WHIT'S JOU AND I DIN'T SONLY BEGANTE DOIN ON MINE"}
# ID like to pay bills due and I don't send it out to do it online
# {'text': "I'D LIKE TO PAY A BILL"}
# ID like to pay the bill
